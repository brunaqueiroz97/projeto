# %% [markdown]
# ### Calling de packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Calling the dataset

# %%
dados = pd.read_csv('piracicaba_2012_2021_ETo.csv', sep = ';')
dados
# Out:
#             date  latitude_graus  longitude_graus  altitude  julian_day  day  \
# 0     01/01/2012          -47.63            -22.7       546           1    1
# 1     02/01/2012          -47.63            -22.7       546           2    2
# 2     03/01/2012          -47.63            -22.7       546           3    3
# 3     04/01/2012          -47.63            -22.7       546           4    4
# 4     05/01/2012          -47.63            -22.7       546           5    5
# ...          ...             ...              ...       ...         ...  ...
# 3648  12/27/2021          -47.63            -22.7       546        3649   27
# 3649  12/28/2021          -47.63            -22.7       546        3650   28
# 3650  12/29/2021          -47.63            -22.7       546        3651   29
# 3651  12/30/2021          -47.63            -22.7       546        3652   30
# 3652  12/31/2021          -47.63            -22.7       546        3653   31
#
#       T_mean  RH_mean  U_z  T_max  ...       svp  svp_tmin  svp_tmax  \
# 0       21.5     99.9  0.9   24.5  ...  2.564420  2.197393  3.074649
# 1       22.5     82.7  1.6   28.7  ...  2.725588  1.901195  3.936754
# 2       24.5     73.0  0.9   31.4  ...  3.074649  1.974877  4.595917
# 3       25.7     70.1  0.7   33.6  ...  3.302286  2.143153  5.201930
# 4       23.5     80.3  0.7   31.5  ...  2.895531  2.281006  4.622069
# ...      ...      ...  ...    ...  ...       ...       ...       ...
# 3648    24.5     72.4  1.8   32.8  ...  3.074649  2.183722  4.973992
# 3649    21.4     87.6  1.7   27.2  ...  2.548771  2.129777  3.607388
# 3650    23.5     75.2  1.4   31.1  ...  2.895531  2.025376  4.518232
# 3651    21.8     89.1  0.9   24.7  ...  2.611872  2.309488  3.111610
# 3652    21.7     91.1  0.9   27.1  ...  2.595970  2.238858  3.586311
#
#            avp  delta_svp  atmos_pres  psy_const  shf  Tmean_K    ETo_PM
# 0     2.633385   0.156903   95.010269   0.063182    0   294.65  0.375108
# 1     2.413992   0.165483   95.010269   0.063182    0   295.65  3.999193
# 2     2.398340   0.183835   95.010269   0.063182    0   297.65  4.947835
# 3     2.574452   0.195648   95.010269   0.063182    0   298.85  4.714384
# 4     2.771584   0.174456   95.010269   0.063182    0   296.65  2.572930
# ...        ...        ...         ...        ...  ...      ...       ...
# 3648  2.591092   0.183835   95.010269   0.063182    0   297.65  3.653819
# 3649  2.512879   0.156067   95.010269   0.063182    0   294.55  1.490007
# 3650  2.460397   0.174456   95.010269   0.063182    0   296.65  4.185023
# 3651  2.415099   0.159437   95.010269   0.063182    0   294.95  0.867022
# 3652  2.653364   0.158589   95.010269   0.063182    0   294.85  1.756735
#
# [3653 rows x 26 columns]

# %%
#Preprocessing
del dados['svp']
del dados['svp_tmin']
del dados['svp_tmax']
del dados['avp']
del dados['delta_svp']
del dados['atmos_pres']
del dados['psy_const']
del dados['shf']
del dados['Tmean_K']
dados = dados.dropna()
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3622 entries, 0 to 3652
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             3622 non-null   object
#  1   latitude_graus   3622 non-null   float64
#  2   longitude_graus  3622 non-null   float64
#  3   altitude         3622 non-null   int64
#  4   julian_day       3622 non-null   int64
#  5   day              3622 non-null   int64
#  6   T_mean           3622 non-null   float64
#  7   RH_mean          3622 non-null   float64
#  8   U_z              3622 non-null   float64
#  9   T_max            3622 non-null   float64
#  10  RH_max           3622 non-null   float64
#  11  T_min            3622 non-null   float64
#  12  RH_min           3622 non-null   float64
#  13  precipitation    3622 non-null   float64
#  14  R_s              3622 non-null   float64
#  15  R_n              3622 non-null   float64
#  16  ETo_PM           3622 non-null   float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 509.3+ KB

# %% [markdown]
# ### Calling sklearn packages

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
#features and label
X = dados[['T_mean', 'RH_mean', 'U_z', 'R_n']]
y = dados['ETo_PM']
#splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#escale the data
scaler = StandardScaler()
X_trained = scaler.fit_transform(X_train)
X_testscaled = scaler.fit_transform(X_test)
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Running the model

# %%
svr = SVR(C = 1.0, epsilon = 0.1).fit(X_trained, y_train)

# %%
#Train score
svr.score(X_trained, y_train)
# Out:
# 0.9923997085282233

# %%
#Test score
svr.score(X_testscaled, y_test)
# Out:
# 0.9914721906017018

# %%
#Validation score using k-fold (cross validation (cv) - k = 10 folders)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(svr, X, y, cv = 10, scoring = 'r2')
#scores = acurácia de todos os folders 
print('%0.2f accuracy with a standar deviation of %0.2f' % (scores.mean(), scores.std()))
#media de todos os 10 folders e seu desvio padrão
# Out:
# 0.98 accuracy with a standar deviation of 0.00

# %% [markdown]
# ### Results of the model

# %%
print('A precisão do modelo de treino foi: {:.2f}%' .format(100*(svr.score(X_trained, y_train))))
print('A precisão do modelo de teste foi: {:.2f}%' .format(100*(svr.score(X_testscaled, y_test))))
print('A precisão do modelo de validação foi: {:.2f}%' .format(100*(scores.mean())))
print('O RMSE do modelo de treino foi: {:.2f}' .format((mean_squared_error(y_train, svr.predict(X_trained), squared=False))))
print('O RMSE do modelo de teste foi: {:.2f}' .format((mean_squared_error(y_test, svr.predict(X_testscaled), squared=False))))
# Out:
# A precisão do modelo de treino foi: 99.24%
# A precisão do modelo de teste foi: 99.15%
# A precisão do modelo de validação foi: 98.41%
# O RMSE do modelo de treino foi: 0.11
# O RMSE do modelo de teste foi: 0.12

# %% [markdown]
# ### Salvando o modelo

# %%
import joblib as jb
#Save the model as a pickle in a file
jb.dump(svr, 'eto_svr.pkl')
# Out:
# ['eto_svr.pkl']

# %% [markdown]
# ### Calculando ETo com base no algoritmo treinado

# %%
#open new datas
df = pd.read_csv('dados_algoritmos.csv', sep = ';')
#features and label
X_new = df[['T_mean', 'RH_mean', 'U_z', 'R_n']]
scaler = StandardScaler()
X_scaled_new = scaler.fit_transform(X_new)

# %%
predicted_values = pd.DataFrame(regr.predict(X_scaled_new), columns=['predict_result'])
predicted_values
# Out:
#    predict_result
# 0        2.930567
# 1        2.261952
# 2        3.150740
# 3        4.341340
# 4        0.922841
# 5        1.885117
# 6        0.015609
# 7        3.815182
# 8        4.059970

# %%
predicted_values.to_excel('ETo_predict_SVR.xlsx', index = False)

# %%
#Turning the label column in a DataFrame (ETo_PM)
y = pd.DataFrame(y)
type(y)
y
# Out:
#         ETo_PM
# 0     0.375108
# 1     3.999193
# 2     4.947835
# 3     4.714384
# 4     2.572930
# ...        ...
# 3648  3.653819
# 3649  1.490007
# 3650  4.185023
# 3651  0.867022
# 3652  1.756735
#
# [3622 rows x 1 columns]

# %% [markdown]
# ## Making a regression with true and predicted values

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
#(ETo_PM, ETo_HGBR)
model.fit(y, predicted_values)
model.intercept_, model.coef_
# Out:
# (array([0.04089522]), array([[0.98350915]]))

# %%
line = np.linspace(0, 8, 100)

# %%
x_new = np.linspace(0, 7, 100)
y_new = model.predict(x_new[:, np.newaxis])

# plot the results
plt.figure(figsize=(8, 8))
ax = plt.axes()
ax.scatter(y, predicted_values, color = 'blue', alpha=0.3)
ax.plot(x_new, y_new, color = 'crimson', linewidth = 3)


ax.set_xlabel('Predicted_values')
ax.set_ylabel('True_values')

ax.axis('tight')
plt.show()

# %% [markdown]
# ## Comparing true ETo-PM and predicted ETo

# %%
plt.figure(figsize = (40, 8))
ax = plt.axes()
ax.plot(dados['julian_day'], dados['ETo_PM'])
ax.plot(dados['julian_day'], regr.predict(X_scaled))

#axis labels
ax.set_xlabel('julian_day (day)')
ax.set_ylabel('ETo (mm day^-1)')

#limite dos eixos
ax.axis(xmin = 0, xmax = 3660)
plt.savefig('MLPR.png')
plt.show()
